# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import os
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../model')
sys.path.append('../../cost')
sys.path.append('../../constraints')
sys.path.append('../../utils')

# %%
import UnicycleModel
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from matplotlib.patches import Ellipse
from utils_alg import get_neighbor_vec,get_K_discrete
from utils_plot import plot_traj,plot_traj_set,plot_state_input
from Single_PTR import Single_PTR
from utils_alg import get_sample_eta_w,propagate_model
import cvxpy as cvx
from scipy.integrate import solve_ivp
from EstimatingLipschitz import Lipschitz
from LMI import Q_update

# %%
ix = 3
iu = 2
iw = 2
iq = 2
ip = 2
N = 30
tf = 3
delT = tf/N

# %%
# time-invariant matrices
C = np.array([[0,0,1],[0,0,0]])
D = np.array([[0,0],[1,0]])
E = np.array([[1,0],[0,1],[0,0]])
G = np.zeros((iq,iw))

# %% [markdown]
# ## obstacle setting

# %%
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])
# obstacle
c_list = []
H_list = []
c1 = [1,2]
H1 = get_H_obs(0.75,1.5)
c_list.append(c1)
H_list.append(H1)
c2 = [4,3]
H2 = get_H_obs(0.75,1.5)
c_list.append(c2)
H_list.append(H2)

# %% [markdown]
# ## initial and final conditions

# %%
xi = np.zeros(3)
xi[0] = 0.0
xi[1] = 0.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0

xi_margin = np.array([0.1,0.1,np.deg2rad(5)])*2
Qf = np.diag([0.5**2,0.5**2,np.deg2rad(20)**2])*1.5
vec_neighbor = []
xi_neighbor = np.array(get_neighbor_vec(-1,0,ix,None,vec_neighbor)) * np.array(xi_margin) + xi

myModel = UnicycleModel.unicycle('Hello',ix,iu,iw,'numeric_central')
myCost = UnicycleCost.unicycle('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)
myConst.set_obstacle(c_list,H_list)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
u0 = np.zeros((N+1,iu))

A,B,s,z,x_prop_n = myModel.diff_discrete_zoh(x0[0:N,:],u0[0:N,:],delT,tf) 
S = np.eye(ix)
R = 2*np.eye(iu)
Kbar = get_K_discrete(A,B,S,R,S,N,ix,iu)
Qbar = np.tile(np.diag([0.35**2,0.35**2,np.deg2rad(10)**2]),(N+1,1,1))
Ybar = Kbar@Qbar[:N]
xbar,ubar = x0,u0

# %%
plt.figure(0,figsize=(7,7))
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,xi_margin=xi_margin,Qf=Qf,plt=plt)

# %%
history = []
total_iter = 30
for idx_iter in range(total_iter) :
    # step 1 Nominal trajectory update
    i1 = Single_PTR('unicycle',N,tf,1,myModel,myCost,myConst,
              w_c=1,w_vc=1e3,w_tr=1e1,tol_vc=1e-6,tol_tr=1e-4,verbosity=True)
    _,_,xnew,unew,total_num_iter,flag_boundary,l,l_vc,l_tr = i1.run(xbar,ubar,xi,xf,Qbar,Kbar)
    # plt.figure(0,figsize=(7,7))
    # plot_traj_set(xnew,unew,c_list,H_list,Qbar,xi=xi,xf=xf,xi_margin=xi_margin,Qf=Qf,plt=plt)
    # plt.show()
 
    A,B,F,s,z,x_prop_n = myModel.diff_discrete_zoh_noise(xnew,unew,np.zeros((N,iw)),delT,tf) 
    sz = tf*s + z
    # propagation
    xprop,_ = i1.forward_multiple(xnew,unew)

    myM = Lipschitz(ix,iu,iq,ip,iw,N)
    myM.initialize(xnew,unew,xprop,Qbar,Kbar,A,B,C,D,E,F,G,myModel)
    gamma = myM.update_lipschitz_norm(myModel,delT)
#     gamma = myM.update_lipschitz_parallel(myModel,delT)
#     gamma = np.load('gammatest.npy')
    print("mean of gamma",np.mean(gamma,0),"max of gamma",np.max(gamma,0),"var of gamma",np.var(gamma,0))

    # propagation error
    e_prop = np.linalg.norm(xprop - xnew[1:],axis=1)

    myQ = Q_update(ix,iu,iq,ip,iw,N,delT,myCost.S,myCost.R,w_tr=1e1,w_vc=1e4)
    myQ.initialize(xnew,unew,e_prop*0,A,B,C,D,E,F,G)
    alpha = 0.99
    Qnew,Knew,Ynew,status = myQ.solve(alpha,gamma,xi_neighbor,Qf,Qbar,Ybar)
    print("LMI status:" + status)
    
    beta = myQ.update_beta(Qnew,Knew,gamma,alpha)
    for i in range(N+1) :
        Qnew[i] = Qnew[i] * beta[i]
    print(beta)
    
    # plot the trajectory
    plt.figure(1,figsize=(7,7))
    plot_traj_set(xnew,unew,c_list,H_list,Qnew,xi=xi,xf=xf,xi_margin=xi_margin,Qf=Qf,plt=plt)
    plt.show()

    # measure the difference
    xdiff = np.linalg.norm(xbar-xnew)
    udiff = np.linalg.norm(ubar-unew)
    Qdiff = np.linalg.norm(Qbar-Qnew)
    Kdiff = np.linalg.norm(Kbar-Knew)
    Ydiff = np.linalg.norm(Ybar-Ynew)

#     print("xdiff:{:8.5f} udiff:{:8.5f} Qdiff:{:8.5f} Kdiff:{:8.5f} Ydiff:{:8.5f}".format(xdiff,udiff,Qdiff,Kdiff,Ydiff))

    # update trajectory
    xbar = xnew
    ubar = unew
    Qbar = Qnew
    Kbar = Knew
    Ybar = Ynew
    
    # save trajectory
    traj = {}
    traj['x'] = xbar
    traj['u'] = ubar
    traj['Q'] = Qbar
    traj['Y'] = Ybar
    traj['K'] = Kbar
    traj['gamma'] = gamma
    traj['Q_diff'] = Qdiff
    traj['K_diff'] = Kdiff
    history.append(traj)
# Out:
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           5957.181          86.009      5           87.1        -4.96e+03   10.000      0( 5)
# mean of gamma 0.015231192079210682 max of gamma 0.017506714292807674 var of gamma 6.57742107626561e-06
# total_cost      cost         ||vc||     ||tr||
#     58.494        17.7           0        4.08
# LMI status:optimal
# [1.         0.84914253 0.86913266 0.87976053 0.87729326 0.87648002
#  0.87761592 0.87800554 0.87764231 0.87660036 0.87301407 0.86428393
#  0.8564424  0.8526661  0.8497827  0.84753963 0.8457013  0.84413215
#  0.8427069  0.84119325 0.84102076 0.8439811  0.84422953 0.84272946
#  0.84008139 0.83619992 0.8312545  0.82657689 0.82395744 0.82163247
#  0.81930564]
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           1524.484          179.514     3.59e-09    134         -524        10.000      0(3.18)
# mean of gamma 0.017799342768111674 max of gamma 0.045581302039426966 var of gamma 7.823277468967347e-05
# total_cost      cost         ||vc||     ||tr||
#     28.474        22.4           0       0.609
# LMI status:optimal
# [1.         0.83711537 0.84782896 0.8623628  0.8708103  0.8789829
#  0.88262541 0.8763953  0.87367745 0.86616367 0.8575578  0.84898222
#  0.8404924  0.83397437 0.83027602 0.82803618 0.82652243 0.82517649
#  0.8239415  0.82302663 0.82298091 0.82420986 0.8262032  0.82887439
#  0.83027973 0.83293778 0.82650772 0.82421773 0.82085067 0.816525
#  0.81552231]
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           297.080           214.094     1.98e-10    8.3         703         10.000      0(2.44)
# mean of gamma 0.023542663356966902 max of gamma 0.038495988124767296 var of gamma 2.4798137702601338e-05
# total_cost      cost         ||vc||     ||tr||
#     21.813        17.1           0       0.469
# LMI status:optimal
# [1.         0.83693293 0.84385463 0.85229264 0.85991843 0.86579358
#  0.86266291 0.86348204 0.85722419 0.85211682 0.84915874 0.84506934
#  0.84130712 0.83937048 0.83823347 0.83786416 0.83768016 0.83690129
#  0.83557913 0.83458217 0.83512087 0.83672454 0.83961366 0.84224081
#  0.83606994 0.82770924 0.82051084 0.82029892 0.81955575 0.81722941
#  0.81364715]
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           319.921           214.836     8.02e-10    10.5        680         10.000      0(0.611)
# mean of gamma 0.02050212982650888 max of gamma 0.034798605891063025 var of gamma 2.4746527867774495e-05
# total_cost      cost         ||vc||     ||tr||
#     18.869        16.7           0       0.222
# LMI status:optimal
# [1.         0.83675388 0.84710246 0.85942966 0.86175411 0.86479755
#  0.85954287 0.85094744 0.8432888  0.84274137 0.84074039 0.83893184
#  0.83775278 0.8375703  0.83760452 0.8375855  0.83713644 0.83592479
#  0.83376066 0.83111367 0.82903641 0.82755827 0.82655185 0.82543903
#  0.82377456 0.82607443 0.81978356 0.81812803 0.8191574  0.81816406
#  0.81431105]
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           242.873           240.016     4.14e-10    0.286       757         10.000      0(0.00301)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-908f7ead98e2> in <module>
#      17     myM = Lipschitz(ix,iu,iq,ip,iw,N)
#      18     myM.initialize(xnew,unew,xprop,Qbar,Kbar,A,B,C,D,E,F,G,myModel)
# ---> 19     gamma = myM.update_lipschitz_norm(myModel,delT)
#      20 #     gamma = myM.update_lipschitz_parallel(myModel,delT)
#      21 #     gamma = np.load('gammatest.npy')
#
# ~/Documents/Code/Personal/SCP_Funnel_together/Single_SCP_SDP/notebooks/../EstimatingLipschitz.py in update_lipschitz_norm(self, myModel, delT)
#     191                 xii = Kbar[idx]@es
#     192
# --> 193                 xs_prop = propagate_model(myModel,xbar[idx]+es,ubar[idx]+xii,delT)
#     194                 eta_prop = xs_prop - xbar[idx+1]
#     195
#
# ~/Documents/Code/Personal/SCP_Funnel_together/Single_SCP_SDP/notebooks/../../utils/utils_alg.py in propagate_model(model, x0, u, delT)
#     215         return np.squeeze(model.forward(x,u))
#     216
# --> 217     sol = solve_ivp(dfdt,(0,delT),x0,args=(u,),method='RK45',rtol=1e-6,atol=1e-10)
#     218     xnext = sol.y[:,-1]
#     219     return xnext
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     540         method = METHODS[method]
#     541
# --> 542     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     543
#     544     if t_eval is None:
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in __init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      94         self.f = self.fun(self.t, self.y)
#      95         if first_step is None:
# ---> 96             self.h_abs = select_initial_step(
#      97                 self.fun, self.t, self.y, self.f, self.direction,
#      98                 self.error_estimator_order, self.rtol, self.atol)
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/scipy/integrate/_ivp/common.py in select_initial_step(fun, t0, y0, f0, direction, order, rtol, atol)
#     110     y1 = y0 + h0 * direction * f0
#     111     f1 = fun(t0 + h0 * direction, y1)
# --> 112     d2 = norm((f1 - f0) / scale) / h0
#     113
#     114     if d1 <= 1e-15 and d2 <= 1e-15:
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/scipy/integrate/_ivp/common.py in norm(x)
#      59 def norm(x):
#      60     """Compute RMS norm."""
# ---> 61     return np.linalg.norm(x) / x.size ** 0.5
#      62
#      63
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# ~/opt/anaconda3/envs/py308/lib/python3.8/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2528                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2529             else:
# -> 2530                 sqnorm = dot(x, x)
#    2531             ret = sqrt(sqnorm)
#    2532             if keepdims:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
Q_diff_list = [history[i]['Q_diff'] for i in range(idx_iter)]
K_diff_list = [history[i]['K_diff'] for i in range(idx_iter)]

# %%
i_index = np.array([i+1 for i in range(idx_iter)])
fS = 20
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(i_index,Q_diff_list,'o-')
# plt.plot(i_index,i_index*0+tol_Q,'--')
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_Q$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.xticks(i_index)
# plt.legend(fontsize=fS)
plt.subplot(122)
plt.plot(i_index,K_diff_list,'o-')
# plt.plot(i_index,i_index*0+tol_K,'--',label="tolerance")
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_K$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.xticks(i_index)
plt.rcParams["font.family"] = "Times New Roman"
plt.legend(fontsize=fS)

# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/convergence_result.pdf')

# %% [markdown]
# # is it really.. invariant?

# %%
from utils_alg import forward_full_with_K,get_sample_trajectory
import scipy

# %%
xbar = history[-1]['x']
ubar = history[-1]['u']
Qbar = history[-1]['Q']
Ybar = history[-1]['Y']
Kbar = history[-1]['K']

# %%
x0_sample = []
# x0_sample.append(xbar[0])
num_sample = 100
idx = 0
for i in range(num_sample) :
    z = np.random.randn(ix)
    z = z / np.linalg.norm(z)
    x_s = xbar[idx] + scipy.linalg.sqrtm(Qbar[idx])@z
    x0_sample.append(x_s)

# %%
# xsam,usam = forward_full_with_K(x0_sample[98],x,u,K,myModel,N,ix,iu,delT)
tsam,xsam,usam,wsam = get_sample_trajectory(xi,x0_sample,xbar,ubar,Qbar,Ybar,myModel,N,ix,iu,iw,delT,flag_noise=True,discrete=True)

# %%
fS = 15
plt.figure(0,figsize=(7,7))
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,xi_margin=xi_margin,Qf=Qf,plt=plt)
# plt.plot(1e3,1e3,'-',color='tab:purple',label='trajectory samples')
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"

# %%
fS = 15
plt.figure(0,figsize=(7,7))
for xsam_e in xsam :
    plt.plot(xsam_e[:,0], xsam_e[:,1],'-',markersize=4.0, linewidth=1.0,alpha=0.4,color='tab:purple')
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,xi_margin=xi_margin,Qf=Qf,plt=plt,flag_label=True)
plt.plot(1e3,1e3,'-',color='tab:purple',label='samples')
plt.legend(fontsize=fS)
# plt.grid(False)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/traj_result.pdf')

# %%
fS = 20
plt.figure(0,figsize=(10,5))
alpha = 0.5
t_index = np.array(range(N+1))*delT
for i in range(num_sample) :
    tsam_e = tsam[i]
    xsam_e = xsam[i]
    usam_e = usam[i]
#     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)

    plt.subplot(121)
    plt.plot(tsam_e, usam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
    plt.subplot(122)
    plt.plot(tsam_e, usam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
plt.subplot(121)
plt.plot(tsam_e, usam_e[:,0]*0+myConst.vmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,0],ubar[N-1,0]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.axis([0.0, tf, 0.5, 5])
plt.subplot(122)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmin,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,1],ubar[N-1,1]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.axis([0.0, tf, -3, 3])
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/input_result.pdf')

# %%
fS = 20
plt.figure(0,figsize=(10,5))
alpha = 0.5
t_index = np.array(range(N+1))*delT
for i in range(num_sample) :
    tsam_e = tsam[i]
    xsam_e = xsam[i]
    wsam_e = wsam[i]
#     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)
    plt.subplot(121)
    plt.plot(tsam_e, wsam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
    plt.subplot(122)
    plt.plot(tsam_e, wsam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
plt.subplot(121)
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w1 (m)', fontsize = fS)
plt.axis([0.0, tf, -2, 2])
plt.subplot(122)
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w2 (m)', fontsize = fS)
plt.axis([0.0, tf, -2, 2])
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/input_result.pdf')

# %%
total_dollar = 30000
SG_90 = 1193 + (1213.87-1193)*0.1
SG_90_one = total_dollar * SG_90
TT_50 = 1193 + (1204.5-1193)*0.5
TT_90_one = total_dollar * TT_50
print(TT_90_one-SG_90_one)
