# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import os
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../model')
sys.path.append('../../cost')
sys.path.append('../../constraints')
sys.path.append('../../utils')

# %%
import UnicycleModel
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from matplotlib.patches import Ellipse
from utils_alg import get_neighbor_vec,get_K_discrete
from utils_plot import plot_traj,plot_traj_set,plot_state_input
from Single_PTR import Single_PTR
from utils_alg import get_sample_eta_w,propagate_model
import cvxpy as cvx
from scipy.integrate import solve_ivp
from EstimatingLipschitz import Lipschitz
from LMI import Q_update

# %%
ix = 3
iu = 2
iw = 2
iq = 2
ip = 2
N = 30
tf = 3
delT = tf/N

# %%
# time-invariant matrices
C = np.array([[0,0,1],[0,0,0]])
D = np.array([[0,0],[1,0]])
E = np.array([[1,0],[0,1],[0,0]])
G = np.zeros((iq,iw))

# %% [markdown]
# ## obstacle setting

# %%
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])
# obstacle
c_list = []
H_list = []
c1 = [1,2]
H1 = get_H_obs(0.75,1.5)
c_list.append(c1)
H_list.append(H1)
c2 = [4,3]
H2 = get_H_obs(0.75,1.5)
c_list.append(c2)
H_list.append(H2)

# %% [markdown]
# ## initial and final conditions

# %%
xi = np.zeros(3)
xi[0] = 0.0
xi[1] = 0.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0

Qini = np.diag([0.4**2,0.4**2,np.deg2rad(20)**2])
# Qf = np.diag([0.3**2,0.3**2,np.deg2rad(10)**2])
Qf = np.diag([0.5**2,0.5**2,np.deg2rad(20)**2])*1.5



myModel = UnicycleModel.unicycle('Hello',ix,iu,iw,'numeric_central')
myCost = UnicycleCost.unicycle('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)
myConst.set_obstacle(c_list,H_list)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
u0 = np.zeros((N+1,iu))

A,B,s,z,x_prop_n = myModel.diff_discrete_zoh(x0[0:N,:],u0[0:N,:],delT,tf) 
S = np.eye(ix)
R = 2*np.eye(iu)
Khat = get_K_discrete(A,B,S,R,S,N,ix,iu)
Qhat = np.tile(np.diag([0.35**2,0.35**2,np.deg2rad(10)**2]),(N+1,1,1))
Yhat = Khat@Qhat[:N]
xhat,uhat = x0,u0
betahat = np.ones(N+1)

# %%
plt.figure(0,figsize=(7,7))
plot_traj_set(xhat,uhat,c_list,H_list,Qhat,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt)

# %% [markdown]
# ## choose sample points

# %%
num_sample = 100
zs_sample = [] # sample in sphere that will be projected to ellipse
zw_sample = [] 
for i in range(num_sample) :
    z = np.random.randn(ix)
    zs = z / np.linalg.norm(z) * np.random.uniform(0,1)
    zs_sample.append(zs)
    
    z = np.random.randn(iw)
    zw = z / np.linalg.norm(z) * np.random.uniform(0,1)
    zw_sample.append(zw)

# %% [markdown]
# ## run

# %%
history = []
total_iter = 30
tol_funnel = 1e-3
tol_traj = 1e-4

for idx_iter in range(total_iter) :
    print("STEP 1 : Nominal trajectory update")
    i1 = Single_PTR('unicycle',N,tf,1,myModel,myCost,myConst,
              w_c=1,w_vc=1e3,w_tr=1e1,tol_vc=1e-6,tol_tr=1e-4,verbosity=True)
    _,_,xnew,unew,total_num_iter,flag_boundary,l,l_vc,l_tr = i1.run(xhat,uhat,xi,xf,Qhat,Khat)

    # discretization
    A,B,F,s,z,x_prop_n = myModel.diff_discrete_zoh_noise(xnew,unew,np.zeros((N,iw)),delT,tf) 
    sz = tf*s + z
    # propagation
    xprop,_ = i1.forward_multiple(xnew,unew)
    e_prop = np.linalg.norm(xprop - xnew[1:],axis=1)
    
    print("STEP 2 : Lipschitz constant estimation")
    myM = Lipschitz(ix,iu,iq,ip,iw,N)
    myM.initialize(xnew,unew,xprop,Qhat,Khat,A,B,C,D,E,F,G,myModel,zs_sample,zw_sample)
    gamma = myM.update_lipschitz_norm(myModel,delT)
#     gamma = myM.update_lipschitz_parallel(myModel,delT)
    print("mean of gamma",np.mean(gamma,0),"max of gamma",np.max(gamma,0),"var of gamma",np.var(gamma,0))

    print("STEP 3 : Funnel update via SDP")
    myQ = Q_update(ix,iu,iq,ip,iw,N,delT,myCost.S,myCost.R,w_tr=1e1,w_vc=1e4)
    myQ.initialize(xnew,unew,e_prop*0,A,B,C,D,E,F,G)
    alpha = 0.99
    Qnew,Knew,Ynew,status = myQ.solve(alpha,gamma,Qini,Qf,Qhat,Yhat)
    print("LMI status:" + status)
    
    print("STEP 4 : update beta for invariance")
    betanew = myQ.update_beta(Qnew,Knew,gamma,alpha)
    for i in range(N+1) :
        Qnew[i] = Qnew[i] * betanew[i]
    print("beta max {:}".format(np.max(betanew)))
    
    # plot the trajectory
    plt.figure(1,figsize=(7,7))
    plot_traj_set(xnew,unew,c_list,H_list,Qnew,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt)
    plt.title(str(idx_iter+1)+' iterations',fontsize=15)
    plt.show()

    # measure the difference
    xdiff = np.sum(np.linalg.norm(xhat-xnew,axis=1)**2)
    udiff = np.sum(np.linalg.norm(uhat-unew,axis=1)**2)
    Qdiff = np.sum(np.array([np.linalg.norm(Qhat[i]-Qnew[i],ord='fro') for i in range(N+1)])**2)
    Kdiff = np.sum(np.array([np.linalg.norm(Khat[i]-Knew[i],ord='fro') for i in range(N)])**2)
    Ydiff = np.sum(np.array([np.linalg.norm(Yhat[i]-Ynew[i],ord='fro') for i in range(N)])**2)
    betadiff = np.linalg.norm(betanew-betahat)
    
    # update trajectory
    xhat = xnew
    uhat = unew
    Qhat = Qnew
    Khat = Knew
    Yhat = Ynew
    betahat = betanew
    
    # save trajectory
    traj = {}
    traj['x'] = xhat
    traj['u'] = uhat
    traj['Q'] = Qhat
    traj['Y'] = Yhat
    traj['K'] = Khat
    traj['gamma'] = gamma
    traj['traj_diff'] = xdiff + udiff
    traj['funnel_diff'] = Qdiff + Kdiff
    traj['beta_diff'] = betadiff
    history.append(traj)
    
    if traj['traj_diff'] < tol_traj and traj['funnel_diff'] < tol_funnel :
        print("SUCCESS")
        break
    else :
        print("Accept the step")
# Out:
# STEP 1 : Nominal trajectory update
# [[1.61187005]]
# [[9.96942616]]
#
# [[0.44464664]]
# [[1.85888706]]
#
# [[0.13182553]]
# [[0.44177459]]
#
# [[0.29591582]]
# [[0.29591597]]
#
# [[0.44891918]]
# [[0.44891941]]
#
# [[0.58218262]]
# [[0.58218312]]
#
# [[0.64555525]]
# [[0.64555653]]
#
# [[0.65744892]]
# [[0.65747578]]
#
# [[0.57929196]]
# [[0.64149412]]
#
# [[0.50135607]]
# [[0.59958377]]
#
# [[0.39127979]]
# [[0.49629797]]
#
# [[0.23910184]]
# [[0.36011404]]
#
# [[0.13958469]]
# [[0.25966712]]
#
# [[0.0846131]]
# [[0.19341718]]
#
# [[0.05346765]]
# [[0.14875387]]
#
# [[0.03444625]]
# [[0.11858105]]
#
# [[0.02176059]]
# [[0.09741024]]
#
# [[0.01267257]]
# [[0.08126336]]
#
# [[0.00587764]]
# [[0.06725025]]
#
# [[0.00194456]]
# [[0.05509817]]
#
# [[0.00114114]]
# [[0.04909865]]
#
# [[0.00142842]]
# [[0.04875743]]
#
# [[0.00109113]]
# [[0.04682491]]
#
# [[0.00042007]]
# [[0.04193762]]
#
# [[1.86483439e-05]]
# [[0.03407944]]
#
# [[0.00018266]]
# [[0.02260809]]
#
# [[0.00102918]]
# [[0.00896367]]
#
# [[0.00149814]]
# [[0.00149814]]
#
# [[0.00065882]]
# [[0.00035173]]
#
# [[0.00012839]]
# [[6.02605574e-05]]
#
# [[0.]]
# [[0.]]
#
# FAIL: ValueError
# ----------------------------------------------------------------
# AttributeError                 Traceback (most recent call last)
# <ipython-input-101-abe69d5b34e3> in <module>
#       8     i1 = Single_PTR('unicycle',N,tf,1,myModel,myCost,myConst,
#       9               w_c=1,w_vc=1e3,w_tr=1e1,tol_vc=1e-6,tol_tr=1e-4,verbosity=True)
# ---> 10     _,_,xnew,unew,total_num_iter,flag_boundary,l,l_vc,l_tr = i1.run(xhat,uhat,xi,xf,Qhat,Khat)
#      11
#      12     # discretization
#
# ~/Documents/Code/Personal/SCP_Funnel_together/Single_SCP_SDP/notebooks/../Single_PTR.py in run(self, x0, u0, xi, xf, Q, K, xi_neighbor, xf_margin)
#     342                     expected,self.w_tr,flag_boundary,bc_error_norm))
#     343
# --> 344         return self.xfwd,self.ufwd,self.xnew,self.unew,total_num_iter,flag_boundary,l,l_vc,l_tr
#     345
#     346     def print_eigenvalue(self,A_) :
#
# AttributeError: 'Single_PTR' object has no attribute 'xfwd'

# %%
a = np.expand_dims(np.array([1,0]),1)
a = np.expand_dims(np.array([0,1]),1)
idx = 0
print(a.T@Khat[0]@Qhat[0]@Khat[0].T@a)
# Out:
# [[9.96942616]]

# %%
Khat[0]@Qhat[0]@Khat[0].T
# Out:
# array([[1.61187005e+00, 4.00157765e-20],
#        [4.00157765e-20, 9.96942616e+00]])

# %%
traj_diff_list = [history[i]['traj_diff'] for i in range(idx_iter+1)]
funnel_diff_list = [history[i]['funnel_diff'] for i in range(idx_iter+1)]

# %%
i_index = np.array([i+1 for i in range(idx_iter+1)])
fS = 20
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(i_index,traj_diff_list,'o-')
plt.plot(i_index,i_index*0+tol_traj,'--')
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_T$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.xticks(i_index)
# plt.legend(fontsize=fS)
plt.subplot(122)
plt.plot(i_index,funnel_diff_list,'o-')
plt.plot(i_index,i_index*0+tol_funnel,'--',label="tolerance")
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_F$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.xticks(i_index)
plt.rcParams["font.family"] = "Times New Roman"
plt.legend(fontsize=fS)

# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/convergence_result.pdf')

# %% [markdown]
# # is it really.. invariant?

# %%
from utils_alg import forward_full_with_K,get_sample_trajectory
import scipy

# %%
xbar = history[-1]['x']
ubar = history[-1]['u']
Qbar = history[-1]['Q']
Ybar = history[-1]['Y']
Kbar = history[-1]['K']

# %%
x0_sample = []
# x0_sample.append(xbar[0])
num_sample = 100
idx = 0
for i in range(num_sample) :
    z = np.random.randn(ix)
    z = z / np.linalg.norm(z)
    x_s = xbar[idx] + scipy.linalg.sqrtm(Qbar[idx])@z
    x0_sample.append(x_s)

# %%
# xsam,usam = forward_full_with_K(x0_sample[98],x,u,K,myModel,N,ix,iu,delT)
tsam,xsam,usam,wsam = get_sample_trajectory(xi,x0_sample,xbar,ubar,Qbar,Ybar,myModel,N,ix,iu,iw,delT,flag_noise=True,discrete=True)
# Out:
# /Users/taewankim/Documents/Code/Personal/SCP_Funnel_together/Single_SCP_SDP/notebooks/../../utils/utils_alg.py:189: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(tsam),np.array(xsam),np.array(usam),np.array(wsam)

# %%
fS = 15
plt.figure(0,figsize=(7,7))
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt)
# plt.plot(1e3,1e3,'-',color='tab:purple',label='trajectory samples')
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"

# %%
fS = 15
plt.figure(0,figsize=(7,7))
for xsam_e in xsam :
    plt.plot(xsam_e[:,0], xsam_e[:,1],'-',markersize=4.0, linewidth=1.0,alpha=0.4,color='tab:purple')
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt,flag_label=True)
plt.plot(1e3,1e3,'-',color='tab:purple',label='samples')
plt.legend(fontsize=fS)
# plt.grid(False)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/traj_result.pdf')

# %%
fS = 20
plt.figure(0,figsize=(10,5))
alpha = 0.5
t_index = np.array(range(N+1))*delT
for i in range(num_sample) :
    tsam_e = tsam[i]
    xsam_e = xsam[i]
    usam_e = usam[i]
#     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)

    plt.subplot(121)
    plt.plot(tsam_e, usam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
    plt.subplot(122)
    plt.plot(tsam_e, usam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
plt.subplot(121)
plt.plot(tsam_e, usam_e[:,0]*0+myConst.vmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,0],ubar[N-1,0]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.axis([0.0, tf, 0.5, 5])
plt.subplot(122)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmin,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,1],ubar[N-1,1]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.axis([0.0, tf, -3, 3])
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/input_result.pdf')

# %%
fS = 20
plt.figure(0,figsize=(10,5))
alpha = 0.5
t_index = np.array(range(N+1))*delT
for i in range(num_sample) :
    tsam_e = tsam[i]
    xsam_e = xsam[i]
    wsam_e = wsam[i]
#     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)
    plt.subplot(121)
    plt.plot(tsam_e, wsam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
    plt.subplot(122)
    plt.plot(tsam_e, wsam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
plt.subplot(121)
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w1 (m)', fontsize = fS)
plt.axis([0.0, tf, -2, 2])
plt.subplot(122)
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w2 (m)', fontsize = fS)
plt.axis([0.0, tf, -2, 2])
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('/Users/keemtw/Documents/Study/Note/SCP_invariant_tube/input_result.pdf')
